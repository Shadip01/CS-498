# %%
import json

# %%
log_data = "{\"t\":1706574939669,\"u\":0,\"v\":\"\",\"_courseId\":\"CS 196 - Computer Programming II\",\"_assignmentId\":\"Assignment 1 - Classes and Objects\"}\n{\"|\":0,\"_ls\":1,\"_cs\":0,\"_l\":0,\"_c\":0,\"u\":0,\"t\":1706578168467}\n{\"|\":0,\"_ls\":1,\"_cs\":0,\"_l\":0,\"_c\":0,\"u\":0,\"t\":1706578184623}\n{\"u\":0,\"^\":[0,0,\"class Dog:\\r\\n    '''A class represeting a dog. It includes attributes such as, the name of the dog, its age, and its breed.'''\\r\\n    def __init__(self, name, age, breed ):\\r\\n        '''Initializes a Dog object with name, age, and breed attributes.'''\\r\\n        self.name= name\\r\\n        self.age= age\\r\\n        self.breed= breed\\r\\n\\r\\n    def talk(self):\\r\\n        '''Prints a message indicating the dog is talking.'''\\r\\n        print (f'{self.name} says woof!')\\r\\n\\r\\n    def come(self):\\r\\n        '''Prints a message indicating the dog is coming.'''\\r\\n        print(f'{self.name} runs over')\\r\\n\\r\\n    def sit(self):\\r\\n        '''Prints a message indicading the dog is sitting.'''\\r\\n        print(f'{self.name} sits')\\r\\n\"],\"t\":1706578206506}\n{\"|\":700,\"_ls\":20,\"_cs\":700,\"_l\":19,\"_c\":700,\"u\":0,\"t\":1706578206521}\n{\"t\":1706578216535,\"_#\":\"jyTQS3uAxjG7xa+tYsinAHT9BXs=\"}\n{\"u\":1,\"v\":\"\",\"t\":1706578227615}\n{\"|\":0,\"_ls\":21,\"_cs\":700,\"_l\":20,\"_c\":700,\"u\":1,\"t\":1706578227621}\n{\"u\":1,\"^\":[0,0,\"class Cat:\\r\\n    '''A class represeting a cat. It includes attributes such as, the name of the cat, its age, and its breed.'''\\r\\n    def __init__(self, name, age, breed):\\r\\n        '''Initializes a Cat object with name, age, and breed attributes.'''\\r\\n        self.name= name\\r\\n        self.age= age\\r\\n        self.breed= breed\\r\\n    \\r\\n    def talk(self):\\r\\n        '''Prints a message indicating the cat is talking.'''\\r\\n        print(f'{self.name} says meow!')\\r\\n\\r\\n    def come(self):\\r\\n        '''Prints a message indicating the cat is coming.'''\\r\\n        print(f'{self.name} lazily meanders over')\\r\\n\\r\\n    def sit(self):\\r\\n        '''Prints a message indicating the cat is sitting.'''\\r\\n        print(f'{self.name}gives you a contemptuous look')\\r\\n    \"],\"t\":1706578234980}\n{\"|\":741,\"_ls\":40,\"_cs\":1441,\"_l\":39,\"_c\":1441,\"u\":1,\"t\":1706578234985}\n{\"u\":2,\"v\":\"\",\"t\":1706578240336}\n{\"|\":0,\"_ls\":41,\"_cs\":1441,\"_l\":40,\"_c\":1441,\"u\":2,\"t\":1706578240342}\n{\"u\":2,\"^\":[0,0,\"#Creating 2 different dogs\\r\\ndog1= Dog(name=\\\"Coffee\\\", age=4, breed=\\\"LCCN\\\")\\r\\ndog2= Dog(name=\\\"Julie\\\", age=3, breed=\\\"Dalmation\\\")\"],\"t\":1706578248268}\n{\"|\":124,\"_ls\":43,\"_cs\":1565,\"_l\":42,\"_c\":1565,\"u\":2,\"t\":1706578248274}\n{\"|\":124,\"_ls\":43,\"_cs\":1565,\"_l\":42,\"_c\":1565,\"u\":2,\"t\":1706578255054}\n{\"u\":3,\"v\":\"\",\"t\":1706578260834}\n{\"|\":0,\"_ls\":44,\"_cs\":1565,\"_l\":43,\"_c\":1565,\"u\":3,\"t\":1706578260846}\n{\"u\":3,\"^\":[0,0,\"#Creating 2 different cats\\r\\ncat1=Cat(name=\\\"Martha\\\", age=2, breed=\\\"Siamese\\\")\\r\\ncat2=Cat(name=\\\"Marcy\\\", age=3, breed=\\\"Burmese\\\")\"],\"t\":1706578268638}\n{\"|\":123,\"_ls\":46,\"_cs\":1688,\"_l\":45,\"_c\":1688,\"u\":3,\"t\":1706578268643}\n{\"u\":4,\"v\":\"\",\"t\":1706578272352}\n{\"|\":0,\"_ls\":47,\"_cs\":1688,\"_l\":46,\"_c\":1688,\"u\":4,\"t\":1706578272359}\n{\"u\":4,\"^\":[0,0,\"#Call the talk(), come(), sit() methods for each object\\r\\ndog1.talk()\\r\\ndog1.come()\\r\\ndog1.sit()\\r\\n\\r\\ndog2.talk()\\r\\ndog2.come()\\r\\ndog2.sit()\\r\\n\\r\\ncat1.talk()\\r\\ncat1.come()\\r\\ncat1.sit()\\r\\n\\r\\ncat2.talk()\\r\\ncat2.come()\\r\\ncat2.sit()\"],\"t\":1706578279661}\n{\"|\":213,\"_ls\":62,\"_cs\":1901,\"_l\":61,\"_c\":1901,\"u\":4,\"t\":1706578279666}\n{\"u\":5,\"v\":\"\",\"t\":1706578287235}\n{\"|\":0,\"_ls\":63,\"_cs\":1901,\"_l\":62,\"_c\":1901,\"u\":5,\"t\":1706578287254}\n{\"u\":5,\"^\":[0,0,\"#Print and modify the age for dog1\\r\\nprint(f'The {dog1.breed} named {dog1.name} is {dog1.age} years old now.')\\r\\ndog1.age+=1\\r\\nprint(f'The {dog1.breed} named {dog1.name} is {dog1.age} years old now.')\\r\\n\"],\"t\":1706578296585}\n{\"|\":199,\"_ls\":67,\"_cs\":2100,\"_l\":66,\"_c\":2100,\"u\":5,\"t\":1706578296590}\n{\"t\":1706578306602,\"_#\":\"j3l3KYqBLaDrpqGM7qQy+g/sLug=\"}\n"

# %%
json_strings = log_data.split('\n')

# Parse each JSON string into a Python dictionary and append to a list
parsed_logs = [json.loads(js) for js in json_strings if js]

parsed_formatted_logs = []

for log in parsed_logs:
    new_log = {}
    if 't' in log:
        new_log['t'] = log['t']
    if 'u' in log:
        new_log['u'] = log['u']
    if 'v' in log:
        new_log['v'] = log['v']
    if '^' in log:
        new_log['^'] = log['^']
    if '|' in log:
        new_log['|'] = log['|']
    if '_c' in log:
        new_log['_c'] = log['_c']
    if '_cs' in log:
        new_log['_cs'] = log['_cs']
    if '_l' in log:
        new_log['_l'] = log['_l']
    if '_ls' in log:
        new_log['_ls'] = log['_ls']
    parsed_formatted_logs.append(new_log)

# Printing the formatted logs
for log in parsed_formatted_logs:
    print(log)
# Out:
# {'t': 1706574939669, 'u': 0, 'v': ''}
# {'t': 1706578168467, 'u': 0, '|': 0, '_c': 0, '_cs': 0, '_l': 0, '_ls': 1}
# {'t': 1706578184623, 'u': 0, '|': 0, '_c': 0, '_cs': 0, '_l': 0, '_ls': 1}
# {'t': 1706578206506, 'u': 0, '^': [0, 0, "class Dog:\r\n    '''A class represeting a dog. It includes attributes such as, the name of the dog, its age, and its breed.'''\r\n    def __init__(self, name, age, breed ):\r\n        '''Initializes a Dog object with name, age, and breed attributes.'''\r\n        self.name= name\r\n        self.age= age\r\n        self.breed= breed\r\n\r\n    def talk(self):\r\n        '''Prints a message indicating the dog is talking.'''\r\n        print (f'{self.name} says woof!')\r\n\r\n    def come(self):\r\n        '''Prints a message indicating the dog is coming.'''\r\n        print(f'{self.name} runs over')\r\n\r\n    def sit(self):\r\n        '''Prints a message indicading the dog is sitting.'''\r\n        print(f'{self.name} sits')\r\n"]}
# ...

# %%
logs = log_data.split('\n')

# Initialize an empty list to store parsed log entries
parsed_logs = []

# Iterate over each log entry
for log in logs:
    if log.strip():  # Check if the log entry is not empty
        try:
            # Parse the JSON log entry
            log_entry = json.loads(log)

            # Extract relevant fields
            time = log_entry.get('t')
            cell_number = log_entry.get('u')
            new_value = log_entry.get('v')
            insert_info = log_entry.get('^')
            cursor_position = log_entry.get('|')
            cursor_position_within_file = log_entry.get('_c')
            total_chars_in_file = log_entry.get('_cs')
            current_line_number = log_entry.get('_l')
            total_lines_in_file = log_entry.get('_ls')

            # Create a dictionary for the parsed log entry
            parsed_log_entry = {
                'time': time,
                'cell_number': cell_number,
                'new_value': new_value,
                'insert_info': insert_info,
                'cursor_position': cursor_position,
                'cursor_position_within_file': cursor_position_within_file,
                'total_chars_in_file': total_chars_in_file,
                'current_line_number': current_line_number,
                'total_lines_in_file': total_lines_in_file
            }

            # Append the parsed log entry to the list
            parsed_logs.append(parsed_log_entry)
            print(logs)
        except json.JSONDecodeError as e:
            print(f"Error decoding")
# Out:
# ['{"t":1706574939669,"u":0,"v":"","_courseId":"CS 196 - Computer Programming II","_assignmentId":"Assignment 1 - Classes and Objects"}', '{"|":0,"_ls":1,"_cs":0,"_l":0,"_c":0,"u":0,"t":1706578168467}', '{"|":0,"_ls":1,"_cs":0,"_l":0,"_c":0,"u":0,"t":1706578184623}', '{"u":0,"^":[0,0,"class Dog:\\r\\n    \'\'\'A class represeting a dog. It includes attributes such as, the name of the dog, its age, and its breed.\'\'\'\\r\\n    def __init__(self, name, age, breed ):\\r\\n        \'\'\'Initializes a Dog object with name, age, and breed attributes.\'\'\'\\r\\n        self.name= name\\r\\n        self.age= age\\r\\n        self.breed= breed\\r\\n\\r\\n    def talk(self):\\r\\n        \'\'\'Prints a message indicating the dog is talking.\'\'\'\\r\\n        print (f\'{self.name} says woof!\')\\r\\n\\r\\n    def come(self):\\r\\n        \'\'\'Prints a message indicating the dog is coming.\'\'\'\\r\\n        print(f\'{self.name} runs over\')\\r\\n\\r\\n    def sit(self):\\r\\n        \'\'\'Pr
# ...
